# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahulrama6705/perplexity/blob/main/3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# --- 1. Data Preparation ---
# Simplified English-French parallel corpus
english_sentences = [
    "I am a student.",
    "How are you?",
    "This is a book.",
    "She likes to read.",
    "We are learning machine translation."
]

french_sentences = [
    "Je suis un étudiant.",
    "Comment allez-vous ?",
    "C'est un livre.",
    "Elle aime lire.",
    "Nous apprenons la traduction automatique."
]

# Add start and end tokens to target sequences for training
french_sentences_input = ['<start> ' + sentence for sentence in french_sentences]
french_sentences_target = [sentence + ' <end>' for sentence in french_sentences]

# Tokenization for English (Encoder Input)
eng_tokenizer = Tokenizer(num_words=None, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~\t\n')
eng_tokenizer.fit_on_texts(english_sentences)
eng_input_sequences = eng_tokenizer.texts_to_sequences(english_sentences)
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_max_seq_len = max(len(seq) for seq in eng_input_sequences)

# Tokenization for French (Decoder Input and Target Output)
# Remove '<' and '>' from filters to preserve <start> and <end> tokens
fra_tokenizer = Tokenizer(num_words=None, filters='!"#$%&()*+,-./:;=?@[\]^_`{|}~\t\n')
fra_tokenizer.fit_on_texts(frozenset(french_sentences_input + french_sentences_target)) # Fit on both to ensure all tokens are included
fra_input_sequences = fra_tokenizer.texts_to_sequences(frozenset(french_sentences_input))
fra_target_sequences = fra_tokenizer.texts_to_sequences(frozenset(french_sentences_target))
fra_vocab_size = len(fra_tokenizer.word_index) + 1
fra_max_seq_len = max(len(seq) for seq in fra_input_sequences + fra_target_sequences)

# Pad sequences to ensure uniform length
encoder_input_data = pad_sequences(eng_input_sequences, maxlen=eng_max_seq_len, padding='post')
decoder_input_data = pad_sequences(fra_input_sequences, maxlen=fra_max_seq_len, padding='post')

# Prepare decoder target data (one-hot encoded)
decoder_target_data = np.zeros(
    (len(french_sentences), fra_max_seq_len, fra_vocab_size),
    dtype='float32'
)

for i, seq in enumerate(fra_target_sequences):
    for j, word_index in enumerate(seq):
        if word_index > 0: # Ensure not padding (0)
            decoder_target_data[i, j, word_index] = 1.

print(f"Encoder Input Shape: {encoder_input_data.shape}")
print(f"Decoder Input Shape: {decoder_input_data.shape}")
print(f"Decoder Target Shape: {decoder_target_data.shape}")

# --- 2. Model Architecture ---
latent_dim = 256 # Dimensionality of the encoding space.

# Encoder
encoder_inputs = Input(shape=(None,))
encoder_embedding = Embedding(eng_vocab_size, latent_dim)(encoder_inputs)
encoder_lstm, state_h, state_c = LSTM(latent_dim, return_state=True)(encoder_embedding)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(None,))
decoder_embedding = Embedding(fra_vocab_size, latent_dim)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense = Dense(fra_vocab_size, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the full model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# --- 3. Training ---
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')

print("\nTraining the model (this will be quick due to small dataset)...\n")
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=len(english_sentences), # Use all data in one batch for this small example
    epochs=100,
    validation_split=0.0
)

# --- 4. Inference (Prediction) Model ---
# Encoder model (extracts states from encoder_inputs)
encoder_model = Model(encoder_inputs, encoder_states)

# Decoder model setup (takes encoder states as initial states)
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_embedding,
    initial_state=decoder_states_inputs
)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states
)

# Reverse lookup dictionaries for decoding sequences back to words
reverse_eng_word_index = dict((i, word) for word, i in eng_tokenizer.word_index.items())
reverse_fra_word_index = dict((i, word) for word, i in fra_tokenizer.word_index.items())

def decode_sequence(input_seq):
    # Encode the input sequence to get the internal state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1 with the start token
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = fra_tokenizer.word_index['<start>']

    # Sampling loop for a batch of sequences
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word = reverse_fra_word_index.get(sampled_token_index, '')
        decoded_sentence += ' ' + sampled_word

        # Exit condition: either hit max length or find stop token.
        if (sampled_word == '<end>' or len(decoded_sentence.split()) > fra_max_seq_len):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update states
        states_value = [h, c]
    return decoded_sentence.replace(' <end>', '').strip()

# --- 5. Test the model ---
print("\n--- Testing the model ---")
for seq_index in range(len(encoder_input_data)):
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print(f"Input: {english_sentences[seq_index]}")
    print(f"Actual: {french_sentences[seq_index]}")
    print(f"Predicted: {decoded_sentence}")
    print('--')
# Out:
# Encoder Input Shape: (5, 5)
# Decoder Input Shape: (5, 6)
# Decoder Target Shape: (5, 6, 20)
#
# Training the model (this will be quick due to small dataset)...
#
# Epoch 1/100
# <>:31: SyntaxWarning: invalid escape sequence '\]'
# <>:39: SyntaxWarning: invalid escape sequence '\]'
# <>:31: SyntaxWarning: invalid escape sequence '\]'
# <>:39: SyntaxWarning: invalid escape sequence '\]'
# /tmp/ipython-input-717293244.py:31: SyntaxWarning: invalid escape sequence '\]'
#   eng_tokenizer = Tokenizer(num_words=None, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~\t\n')
# /tmp/ipython-input-717293244.py:39: SyntaxWarning: invalid escape sequence '\]'
#   fra_tokenizer = Tokenizer(num_words=None, filters='!"#$%&()*+,-./:;=?@[\]^_`{|}~\t\n')
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 2.2942
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 2.2754
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 2.2591
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 2.2426
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2.2245
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2.2034
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 2.1778
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 2.1453
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2.1034
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 2.0515
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.9978
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.9624
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.9450
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.9232
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.9033
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8814
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8605
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8387
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8195
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8011
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.7867
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 1.7682
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.7548
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.7197
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.7504
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.6973
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 1.7076
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.5862
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.5438
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.4696
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.4162
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.3471
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.2940
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.2501
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.2235
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.2336
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.1259
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 1.0966
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.0266
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 1.0481
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.9485
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.9974
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.8824
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.9169
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.8192
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.8997
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.7634
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.7875
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.7096
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.8082
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.6693
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.7247
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.6222
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.7465
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.5946
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.6067
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.5535
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.6123
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.5404
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.7003
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.5151
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.5084
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.4725
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.4741
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.4535
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.4954
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - loss: 0.4596
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.6533
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.4344
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.4258
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.3890
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.3989
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.3657
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.4402
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.3770
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.6047
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.3973
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.3644
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.3502
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.3361
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.3382
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.3254
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.3326
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.3222
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.3293
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.3193
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.3204
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.3105
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.3126
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.2969
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.3404
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.2879
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.4897
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.3038
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.3757
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.2909
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.3927
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.2716
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.3079
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.2505
#
# --- Testing the model ---
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Input: I am a student.
# Actual: Je suis un étudiant.
# Predicted: c'est un livre
# --
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Input: How are you?
# Actual: Comment allez-vous ?
# Predicted: nous apprenons la traduction automatique
# --
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Input: This is a book.
# Actual: C'est un livre.
# Predicted: elle aime lire
# --
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Input: She likes to read.
# Actual: Elle aime lire.
# Predicted: je suis un
# --
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Input: We are learning machine translation.
# Actual: Nous apprenons la traduction automatique.
# Predicted: comment allez vous
# --
# '\n### Flow of the Seq2Seq Encoder-Decoder Model for English-to-French Translation:\n\n1.  **Data Preparation:**\n    *   **Corpus:** We start with parallel sentences in English and French. For the French sentences, special `<start>` and `<end>` tokens are added to mark the beginning and end of a sequence, which is crucial for the decoder during training and inference.\n    *   **Tokenization:** `Tokenizer` from Keras is used to convert words into numerical indices. It builds a vocabulary from the provided text.\n        *   `eng_tokenizer` for English sentences.\n        *   `fra_tokenizer` for French sentences (fitted on both input and target French sentences to ensure all potential words are in the vocabulary).\n    *   **Sequence Conversion:** Text sentences are converted into sequences of integer indices.\n    *   **Padding:** `pad_sequences` is applied to make all sequences the same length by adding zeros. This is necessary for batch processing in neural networks.\n    *   **One-Hot Encoding for Decoder Target:** The decoder\'s target output needs to be in a one-hot encoded format. Each word in the French target sequences is converted into a vector where only the index corresponding to that word is 1, and all others are 0. This is because the decoder predicts the probability distribution over the entire vocabulary for each output step.\n\n2.  **Model Architecture:**\n    *   **Encoder:**\n        *   Takes the English input sequence (integer indices).\n        *   An `Embedding` layer converts each word index into a dense vector representation (`latent_dim`).\n        *   An `LSTM` (Long Short-Term Memory) layer processes the embedded sequence. It captures the context and meaning of the input sentence into a fixed-size vector representation, specifically its final hidden state (`state_h`) and cell state (`state_c`). These states collectively represent the "context" or "thought vector" of the input sentence.\n    *   **Decoder:**\n        *   Takes the French input sequence (integer indices, which are the `<start>`-prefixed sentences).\n        *   Another `Embedding` layer converts these indices into dense vectors.\n        *   A second `LSTM` layer is used. **Crucially, its initial hidden and cell states are initialized with the final states from the encoder.** This is how the decoder receives the context from the encoder.\n        *   The decoder LSTM is configured with `return_sequences=True` to output a sequence of hidden states (one for each time step) and `return_state=True` to pass its final states to the next step during inference.\n        *   A `Dense` layer with `softmax` activation is applied to the decoder\'s output at each time step. This layer predicts the probability distribution over the entire French vocabulary, effectively predicting the next word.\n    *   **Full Training Model:** A `Model` is defined that takes both `encoder_inputs` and `decoder_inputs` and outputs `decoder_outputs`.\n\n3.  **Training:**\n    *   **Compilation:** The model is compiled with an `optimizer` (e.g., \'rmsprop\') and a `loss` function (`categorical_crossentropy`), suitable for multi-class classification (predicting the next word from the vocabulary).\n    *   **Fitting:** The model is trained using `model.fit()`. It takes the `encoder_input_data`, `decoder_input_data` (the `<start>`-prefixed French sentences), and `decoder_target_data` (the one-hot encoded `<end>`-suffixed French sentences) as inputs.\n\n4.  **Inference (Prediction) Model:**\n    *   During training, the decoder receives the entire target sequence shifted. For prediction, however, it must generate one word at a time based on its previous output.\n    *   **Encoder Model (Inference):** A separate `encoder_model` is created to take an English input sequence and output only its final hidden and cell states. This is the first step in translating a new sentence.\n    *   **Decoder Model (Inference):** A `decoder_model` is built. It takes the previous output wor ...
